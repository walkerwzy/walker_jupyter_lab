# %% [markdown]
# ### OpenCV

# %% [markdown]
# OpenCV是计算机视觉中经典的专用库，其支持多语言、跨平台，功能强大。
#
# OpenCV-Python为OpenCV提供了Python接口，使得使用者在Python中能够调用C/C++，在保证易读性和运行效率的前提下，实现所需的功能。
#
# OpenCV-Python Tutorials官方文档：https://docs.opencv.org/4.1.2/d6/d00/tutorial_py_root.html

# %% [markdown]
# ----

# %% [markdown]
# #### OpenCV的安装

# %% [markdown]
# pip install opencv-python -i https://pypi.tuna.tsinghua.edu.cn/simple

# %% [markdown]
# 查看是否安装成功

# %% [raw]
# >>> import cv2
# >>>

# %% [markdown]
# ---

# %% [markdown]
# ### OpenCV基础操作

# %% [markdown]
# ### 三种常见的色彩空间：
#
# - RGB
# - GRAY
# - HSV

# %% [markdown]
# ![avatar](./00_img/rhg.png)

# %% [markdown]
# #### RGB

# %% [markdown]
# ![avatar](./00_img/rgb.png)
#
#
# RGB常见颜色表
#
# ![avatar](./00_img/rgb1.png)

# %% [markdown]
# ### HSV
#
# HSV即Hue(色调),Saturation(饱和度)和Value(亮度)三个channel

# %% [markdown]
# ![avatar](./00_img/hsv.png)

# %% [markdown]
# ---

# %% [markdown]
# ### HSV 与 RGB之间的转换(了解)

# %% [markdown]
# ### rgb - hsv
#
#
# ![avatar](./00_img/zh3png.png)
# ![avatar](./00_img/zh2-1.png)
# ![avatar](./00_img/zh2-2.png)
#
#
#
# ### hsv - rgb
# ![avatar](./00_img/zh2.png)
# ![avatar](./00_img/zh1.png)

# %% [markdown]
# ---

# %% [raw]
# for i in dir(cv2):
#     if "COLOR_BGR" in i:
#         print(i)

# %% [markdown]
# ### 读取图片并显示图片

# %% [raw]
# import cv2
#
#
# image = cv2.imread("./00_img/cv2.png")  # 默认为 RGB
#
# image_gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
#
# image_hsv = cv2.cvtColor(img,cv2.COLOR_BGR2HSV)
#
# # 显示图片
# cv2.imshow("cbq_rgb", image)
# cv2.imshow("cbq_gray", image_gray)
# cv2.imshow("cbq_hsv", image_hsv)
#
# # 保存图片，在开发的时候，我们通常将计算得到的图片通过保存在本地进行图片的查看
# cv2.imwrite("./cbq_rgb.jpg", image)
# cv2.imwrite("./cbq_gray.jpg", image_gray)
# cv2.imwrite("./cbq_hsv.jpg", image_hsv)
#
# if cv2.waitKey(0) == ord("q"):  # It returns the code of the pressed key
#     cv2.destroyAllWindows()
# """
# cv2.waitKey(0) 0/-1 表示无限等待
# cv2.waitKey(t) 中t参数是时间尺度，这个时间尺度是毫秒级别
# """

# %% [markdown]
# #### 图像的坐标轴显示
#
# ![avatar](./00_img/zxxy.png)

# %% [markdown]
# ### 输入字符进行操作
#
# 仅仅输入一个字符，按任意键即可退出，但是如果有多个键时，需要指定。

# %% [raw]
# import cv2
#
# image = cv2.imread("./temp/00_img/cv2.jpg")
# while True:
#     cv2.imshow("image", image)
#     key = cv2.waitKey(1000)
#
#     if key == ord("q"):
#         break
#
#     if key == ord("t"):
#         cv2.waitKey(0)

# %% [markdown]
# ---

# %% [markdown]
# ### 对视频操作

# %% [markdown]
# 读取视频并显示

# %% [raw]
# import cv2
#
# cap = cv2.VideoCapture("./aa.mp4")  # 读取摄像头，仅仅将视频路径更改为 数字 0 （不同的摄像头有不同的标号）
# print("success")
# while True:
#     ret, frame = cap.read()
#     """
#     cap.read()按帧读取视频，ret,frame是获cap.read()方法的两个返回值。
#     其中ret是布尔值，如果读取帧是正确的则返回True，如果文件读取到结尾，它的返回值就为False。
#     frame就是每一帧的图像，是个三维矩阵。
#     """
#     cv2.imshow("arm", frame)
#     if cv2.waitKey(0) == ord("q"):
#         break
# cap.release()
# cv2.destroyAllWindows()

# %% [markdown]
# 将视频处理为黑白视频

# %% [raw]
# import cv2
#
# cap = cv2.VideoCapture("./aa.mp4")
# print("success")
# while True:
#     ret, frame = cap.read()
#     gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
#     cv2.imshow("arm", gray)
#     if cv2.waitKey(0) == ord("q"):
#         break
# cap.release()
# cv2.destroyAllWindows()

# %% [raw]
# for i in dir(cv2):
#     if "COLOR_BGR" in i:
#         print(i)

# %% [markdown]
# 将视频保存为150张图片

# %% [raw]
# import cv2
#
# cap = cv2.VideoCapture("./aa.mp4")
# print("success")
# for i in range(150):
#     ret, frame = cap.read()
#     gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
#     cv2.imshow("arm", gray)
#     cv2.imwrite(f"./info_pic/{i}.jpg", gray)
#     if cv2.waitKey(0) == ord("q"):
#         break
# cap.release()
# cv2.destroyAllWindows()

# %% [markdown]
# ----

# %% [markdown]
# ### 使用Opencv绘制几何图型
#
# - cv2.line()
# - cv2.rectangle()
# - cv2.circle()
# - cv2.putText()

# %% [raw]
# import numpy as np
#
# 创建一个纯黑色的图片
# image = np.zeros((50, 50, 3), dtype=np.uint8)
#
# 绘制直线：cv2.line()
# cv2.line(image, (0, 0), (49, 49), (0, 255, 255), 5)
#
# 绘制矩形：cv2.rectangle()
# cv2.rectangle(image, (24, 24), (49,49), 5)
#
# 绘制圆形：cv2.circle()
# cv2.circle(image, (24, 24), 20, -1)
#
# 在图片上添加文字
# cv2.putText(image, "(30, 30)", (30, 30), 4, (255, 255, 255), 5)

# %% [markdown]
# ---

# %% [markdown]
# ### OpenCV事件相应-创建可以绘制图像的画板

# %%
import cv2

for i in dir(cv2):
    if "EVENT" in i:
        print(i)
# Out:
# EVENT_FLAG_ALTKEY
# EVENT_FLAG_CTRLKEY
# EVENT_FLAG_LBUTTON
# EVENT_FLAG_MBUTTON
# EVENT_FLAG_RBUTTON
# EVENT_FLAG_SHIFTKEY
# EVENT_LBUTTONDBLCLK
# EVENT_LBUTTONDOWN
# EVENT_LBUTTONUP
# EVENT_MBUTTONDBLCLK
# EVENT_MBUTTONDOWN
# EVENT_MBUTTONUP
# EVENT_MOUSEHWHEEL
# EVENT_MOUSEMOVE
# EVENT_MOUSEWHEEL
# EVENT_RBUTTONDBLCLK
# EVENT_RBUTTONDOWN
# EVENT_RBUTTONUP

# %% [raw]
# cv2_EVENT_MOUSEMOVE    滑动
# cv2_EVENT_LBUTTONDOWN  左键点击
# cv2_EVENT_RBUTTONDOWN  右键点击
# cv2_EVENT_MBUTTONDOWN  中间点击
# cv2_EVENT_LBUTTONUP    左键释放
# cv2_EVENT_RBUTTONUP    右键释放
# cv2_EVENT_MBUTTONUP    中间释放
# cv2_EVENT_LBUTTONDBLCLK左键双击
# cv2_EVENT_RBUTTONDBLCLK右键双击
# cv2_EVENT_MBUTTONDBLCLK中间释放
#
# cv2_EVENT_FLAG_LBUTTON 左键拖拽
# cv2_EVENT_FLAG_RBUTTON 右键拖拽
# cv2_EVENT_FLAG_MBUTTON 中间拖拽

# %% [raw]
# import cv2
#
# def draw_circle(event, x, y, flags, param):
#     if event == cv2.EVENT_MOUSEMOVE and flags == cv2.EVENT_FLAG_LBUTTON:
#         cv2.circle(image, x, y, 1, (255, 0, 0), 5)
#
# image = np.zeros((500, 500, 3), np.int8)
# cv2.setMouseCallback("image", draw_circle)
#
# while True:
#     cv2.imshow("image", image)
#     if cv2.waitKey(0) == ord("q"):
#         break
# cv2.destroyAllWindows()

# %% [markdown]
# ---

# %% [markdown]
# ### OpenCV 实现一个调色板

# %% [markdown]
# BGR调色板

# %% [raw]
# import numpy as np
# import cv2
#
# def nothing(x):
#     pass
#
# image = np.zeros((500, 500, 3), np.uint8)  # rgb
# cv2.namedWindow("image")
#
# cv2.createTrackbar("R", "image", 0, 255, nothing)
# cv2.createTrackbar("G", "image", 0, 255, nothing)
# cv2.createTrackbar("B", "image", 0, 255, nothing)
#
# switch = "0:OFF \n 1:ON"
# cv2.createTrackbar(switch, "image", 0, 1, nothing)
#
# while True:
#     cv2.imshow("image", img)
#     if cv2.waitKey(1) == ord("q"):
#         break
#     r = cv2.getTrackbarPos("R", "image")
#     g = cv2.getTrackbarPos("G", "image")
#     b = cv2.getTrackbarPos("B", "image")
#     s = cv2.getTrackbarPos(switch, "image")
#     if s == 0:
#         img[:] = 0
#     else:
#         img[:] = [r, g, b]
# cv2.destroyWindows()

# %% [markdown]
# HSV 调色板

# %% [raw]
# import cv2
# import numpy as np
#
# def nothing(x): ...
#
# def hsv2rgb_opencv(h, s, v):
#     # params:
#     # h -> [0, 360]
#     # s -> [0, 1]
#     # v -> [0, 1]
#     h = h / 2
#     s = s * 255
#     v = v * 255
#     temp = np.full((1, 1, 3), [h, s, v], np.uint8)
#
#     # cvtColor HSV要求[h=[0, 180], s=[0, 255], v=[0, 255]]
#     b, g, r = cv2.cvtColor(temp, cv2.COLOR_HSV2BGR)[0, 0]
#     return r, g, b
#
#
# def hsv2rgb(h, s, v):
#     # params:
#     # h -> [0, 360]
#     # s -> [0, 1]
#     # v -> [0, 1]
#
#     # 如果h是360，则h/60 = 6，等同于0，所以求模6
#     h = (h / 60) % 6
#     i = int(h)
#
#     f = h - i
#     p = round(v * (1 - s) * 255)
#     q = round(v * (1 - f * s) * 255)
#     t = round(v * (1 - (1 - f) * s) * 255)
#     v = round(v * 255)
#
#     colors = [[v, t, p], [q, v, p], [p, v, t], [p, q, v], [t, p, v], [v, p, q]]
#     return colors[i]
#
#
# winName = "HSV-Palette"
# cv2.namedWindow(winName, cv2.WINDOW_NORMAL)
# cv2.createTrackbar("H", winName, 0, 360, nothing)
# cv2.createTrackbar("S", winName, 0, 100, nothing)
# cv2.createTrackbar("V", winName, 0, 100, nothing)
#
# image = np.zeros((300, 300, 3), np.uint8)
#
# while True:
#
#     h = cv2.getTrackbarPos('H', winName)
#     s = cv2.getTrackbarPos('S', winName)
#     v = cv2.getTrackbarPos('V', winName)
#
#     r, g, b = hsv2rgb(h, s / 100, v / 100)
#     r_, g_, b_ = hsv2rgb_opencv(h, s / 100, v / 100)
#     image[:] = b, g, r
#
#     #print("Custom: ", [r, g, b], "OpenCV: ", [r_, g_, b_])
#
#     cv2.imshow(winName, image)
#     key = cv2.waitKey(1)
#
#     if key & 0xFF == ord('q'):
#         break

# %% [markdown]
# ---

# %% [markdown]
# ### OpenCV 核心操作 -  对图像的操作

# %% [markdown]
# #### 获取图像属性

# %%
import cv2

img = cv2.imread("./00_img/cv2.png")

print(img.shape)  # 获取图像的形状

print(img.size) # 获取图像的像素数目

print(img.dtype)  # 获取图像的数据类型
# Out:
# (217, 212, 3)
# 138012
# uint8

# %% [markdown]
# #### 对图像通道操作

# %% [raw]
# import cv2
#
# img = cv2.imread("./00_img/cv2.png")
#
# img[:,:,2] = 0  # 将红色通道设置为0
#
# cv2.imshow("img", img)
#
# cv2.waitKey(1000)

# %% [markdown]
# #### 图像相加运算

# %% [markdown]
# $g (x) = (1 − α) * f_0 (x) + α * f_1 (x)$
#
# 现在我们把两幅图混合在一起。第一幅图的权重是 0.7，第二幅图的权重是 0.3。
#
#
# 函数 cv2.addWeighted() 可以按下面的公式对图片进行混合操作。
#
# $dst = α · img1 + β · img2 + γ$ 这里 γ 的取值为 0。

# %% [raw]
# import cv2
# import numpy as np
#
# img1=cv2.imread('ml.png')
#
# img2=cv2.imread('opencv_logo.jpg')
#
# size(300, 300)
#
# img1 = cv2.resize(img1, size)
#
# img2 = cv2.resize(img2, size)
#
# dst=cv2.addWeighted(img1,0.7,img2,0.3,0)
#
# cv2.imshow('dst',dst)
#
# cv2.waitKey(0)
#
# cv2.destroyAllWindow()

# %% [markdown]
# #### ROI (region of interest)获取
#
# 有时你需要对一幅图像的特定区域进行操作。
#
# 例如我们要检测一副图像中眼睛的位置，我们首先应该在图像中找到脸，再在脸的区域中找眼睛，而不是直接在一幅图像中搜索。
#
# 这样会提高程序的准确性和性能。

# %% [raw]
# import cv2
#
# img = cv2.imread("./data/cv2.png")
#
# # 86, 77
# # 143, 89
# eyes = img[77:89, 86:143]
# img[0:0,0:0] = eyes
#
# cv2.imshow("img", img)
#
# cv2.waitKey(1000)

# %% [markdown]
# #### 图像简单融合

# %%
import cv2

image1 = cv2.imread("temp/opencvs/frog_logo.png")

row, col, channel = image1.shape

image1 = cv2.resize(image1, (70, 70))

image2 = cv2.imread("temp/opencvs/frog.png")

row, col, channel = image1.shape

image2[0:row, 0:col] = image1

import matplotlib.pyplot as plt

plt.imshow(image2)

# %% [markdown]
# #### 图像高级融合

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

img1 = cv2.imread("./temp/opencvs/frog.png")  # 读取图片img1
img2 = cv2.imread("./temp/opencvs/frog_logo.png")  # 读取图片img2
img2 = cv2.resize(img2, (70, 70))  # 缩小img2的图片尺寸，使用双线性插值法


rows, cols, channels = img2.shape
roi = img1[0:rows, 0:cols, 0:channels]  # 获取img1中感兴趣区域

img2gray = cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY)  # 获取灰度图，方便得到掩码

ret,mask = cv2.threshold(img2gray, 245, 255, cv2.THRESH_BINARY)  # 创建的掩码,<245 == 0，>245 == 255
# """
# cv2.threshhold()。这个函数的第一个参数就是原图像，原图像应该是灰度图。第二个参数就是用来对像素值进行分类的阈值。第三个参数就是当像素值高于（有时是小于）阈值时应该被赋予的新的像素值。
# - cv2.THRESH_BINARY
# - cv2.THRESH_BINARY_INV
# - cv2.THRESH_TRUNC
# - cv2.THRESH_TOZERO
# - cv2.THRESH_TOZERO_INV
# """

mask_inv = cv2.bitwise_not(mask)  # 通过反转上面的图像创建掩码

img1_bg = cv2.bitwise_and(roi, roi, mask=mask)  
# """
# cv2.bitwise_and()是对二进制数据进行“与”操作，即对图像（灰度图像或彩色图像均可）每个像素值进行二进制“与”操作
# 利用掩膜（mask）进行“与”操作，即掩膜图像白色区域是对需要处理图像像素的保留，黑色区域是对需要处理图像像素的剔除
# """

img2_fg = cv2.bitwise_and(img2, img2, mask=mask_inv) # 仅仅显示logo

dst2 = cv2.add(img1_bg, img2_fg)
img1[0:rows, 0:cols] = dst2

plt.imshow(img1, cmap='gray')

# %% [markdown]
# ---

# %% [markdown]
# ### 颜色物体分割
#
# - 彩色图像增加了色彩信息，可以通过不同的色彩值来分割图像，常用彩色空间HSV/HSI, RGB, LAB
#
# - inrange() 来划分颜色区域

# %% [markdown]
# ### RGB

# %% [raw]
# import cv2
# import numpy as np
# cap=cv2.VideoCapture("tt.mp4")
# while(1):
#     # 获取每一帧
#     ret,frame=cap.read()# ret-false, true; frame -- image cv2 bgr
#     # 转换到 HSV
#     # hsv=cv2.cvtColor(frame,cv2.COLOR_BGR2HSV)
#     # 设定蓝色的阈值
#     lower_blue=np.array([50,150,200])
#     """
#     [0,0,0] --- [255,255,255]
#     [0,0,50] --- [255,255,255]
#     [0,50,50] --- [255,255,255]
#     """
#     upper_blue=np.array([255,255,255])
#     # 根据阈值构建掩模
#     mask=cv2.inRange(frame,lower_blue,upper_blue)  # 此时设置的为BGR三色通道
#     # 对原图像和掩模进行位运算
#     res=cv2.bitwise_and(frame,frame,mask=mask)
#     # 显示图像
#     cv2.imshow('frame',frame)
#     # cv2.imshow('mask',mask)
#     cv2.imshow('res',res)
#     k=cv2.waitKey(5)
#     if k==ord("q"):
#         break
#     # 关闭窗口
# cv2.destroyAllWindows()

# %% [markdown]
# ### HSV

# %% [raw]
# import cv2
# import numpy as np
# cap=cv2.VideoCapture("tt.mp4")
# while(1):
#     # 获取每一帧
#     ret,frame=cap.read()  # rgb
#     # 转换到 HSV
#     hsv=cv2.cvtColor(frame,cv2.COLOR_BGR2HSV) # RGB
#     # 设定蓝色的阈值
#     lower_blue=np.array([202,0,0])
#     upper_blue=np.array([255,255,255])
#     # 根据阈值构建掩模
#     mask=cv2.inRange(hsv,lower_blue,upper_blue)  # 此时设置的为BGR三色通道
#     # 对原图像和掩模进行位运算
#     res=cv2.bitwise_and(frame,frame,mask=mask)
#     # 显示图像
#     cv2.imshow('frame',frame)
#     # cv2.imshow('mask',mask)
#     cv2.imshow('res',res)
#     k=cv2.waitKey(5)
#     if k==ord("q"):
#         break
#     # 关闭窗口
# cv2.destroyAllWindows()
